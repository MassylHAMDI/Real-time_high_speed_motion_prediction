# %%
import numpy as np
flow_local = np.load('flow_local_out.npy')
corrected_flow = np.load('corrected_flow_out.npy')

# %%
flow_local[0:10,0].shape
# Out:
# (10,)

# %%
import matplotlib.pyplot as plt
# Créer un diagramme polaire
ax = plt.subplot(111, polar=True)
# Tracer les données pour ARMS
ax.bar(corrected_flow[0:,1], corrected_flow[0:,0]*10000, width=0.2, alpha=0.5, label='ARMS-Flow')
ax.bar(flow_local[0:,1], flow_local[0:,0]*10000, width=0.2, alpha=0.5, label='EDL-Flow')


# Tracer les données pour EDL
ax.set_theta_zero_location('E') 
ax.set_theta_direction(1)  

# Ajouter des légendes, des titres, etc.
ax.set_title("Direction distributions")
ax.legend()

plt.show()

# %%
corrected_flow[0:30,1]
# Out:
# array([2.346535  , 0.        , 0.8818623 , 1.5400677 , 0.        ,
#        1.5210074 , 0.8779168 , 1.183836  , 1.5387087 , 0.        ,
#        1.2243154 , 1.3608546 , 1.4113721 , 0.89731926, 0.        ,
#        0.        , 1.8678325 , 1.1723827 , 1.0608015 , 2.320281  ,
#        1.1729958 , 0.        , 1.5796661 , 1.1497834 , 1.5307318 ,
#        0.        , 0.3758207 , 1.5377474 , 0.        , 1.185587  ],
#       dtype=float32)
